# %% [markdown]
# # Rational experssions excersices 1.4

# %%
from sympy import *
from IPython.display import Math

# %%
x,y,z,c,t,a,b,h,s,r,u = symbols('x,y,z,c,t,a,b,h,s,r,u')

# %% [markdown]
# ## Ques 7-16 - Simplify the rational expression

# %%
exprs = [
    cancel((3*(x + 2)*(x - 1)) / (6*(x - 1)**2)),
    cancel((4*(x**2 - 1)) / (12*(x + 2)*(x - 1))),
    cancel((x - 2) / (x**2 - 4)),
    cancel((x**2 - x - 2) / (x**2 - 1)),
    cancel((x**2 + 6*x + 8) / (x**2 + 5*x + 4)),
    cancel((x**2 - x - 12) / (x**2 + 5*x + 6)),
    cancel((y**2 + y) / (y**2 - 1)),
    # cancel((y**2 - 3*y - 18) / (2*y**2 + 5*y + 3)),
    factor(y**2 - 3*y - 18) / factor(2*y**2 + 5*y + 3),
    cancel((2*x**3 - x**2 - 6*x) / (2*x**2 - 7*x + 6)),
    cancel((1 - x**2) / (x**3 - 1)),
]

def gen_exprs(exprs, ques_start):
    for i, expr in enumerate(exprs, start=ques_start):
        display(Math(f"{i}: {latex(expr)}"))

gen_exprs(exprs, ques_start=7)
# Out:
# $\displaystyle 7: \frac{x + 2}{2 x - 2}$
# $\displaystyle 8: \frac{x + 1}{3 x + 6}$
# $\displaystyle 9: \frac{1}{x + 2}$
# $\displaystyle 10: \frac{x - 2}{x - 1}$
# $\displaystyle 11: \frac{x + 2}{x + 1}$
# $\displaystyle 12: \frac{x - 4}{x + 2}$
# $\displaystyle 13: \frac{y}{y - 1}$
# $\displaystyle 14: \frac{\left(y - 6\right) \left(y + 3\right)}{\left(y + 1\right) \left(2 y + 3\right)}$
# $\displaystyle 15: \frac{2 x^{2} + 3 x}{2 x - 3}$
# $\displaystyle 16: \frac{- x - 1}{x^{2} + x + 1}$

# %% [markdown]
# ## Ques. 17-30 . Perform the multiplication or division and simplify.

# %%
exprs_2 = [
    cancel(((4*x) / (x**2 - 4))*((x + 2)/(16*x))),
    cancel(((x**2 - 25) / (x**2 - 16))*((x + 4)/(x + 5))),
    cancel(((x**2 - x - 12) / (x**2 - 9))*((3 + x)/(4 - x))),
    cancel(((x**2 + 2*x - 3) / (x**2 - 2*x - 3))*((3 - x)/(3 + x))),
    cancel(((t - 3) / (t**2 + 9))*((t + 3)/(t**2 - 9))),
    cancel(((x**2 - x - 6) / (x**2 + 2*x))*((x**3 + x**2)/(x**2 - 2*x - 3))),
    cancel(((x**2 + 7*x + 12) / (x**2 + 3*x + 2))*((x**2 + 5*x + 6)/(x**2 + 6*x + 9))),
    cancel(((x**2 + 2*x*y + y**2) / (x**2 - y**2))*((2*x**2 - x*y - y**2)/(x**2 - x*y - 2*y**2))),
    cancel(((2*x**2 + 3*x + 1) / (x**2 + 2*x - 15))/((x**2 + 6*x + 5)/(2*x**2 - 7*x + 3))),
    cancel(((4*y**2 - 9) / (2*y**2 + 9*y - 18))/((2*y**2 + y - 3)/(y**2 + 5*y - 6))),
    cancel(((x**3) / (x + 1))/((x)/(x**2 + 2*x + 1))),
    cancel(((2*x**2 - 3*x - 2) / (x**2 - 1))/((2*x**2 + 5*x + 2)/(x**2 + x - 2))),
    cancel(((x) / (y))/(z)),
    cancel((x)/(y / z)),

]

gen_exprs(exprs_2, ques_start=17)
# Out:
# $\displaystyle 17: \frac{1}{4 x - 8}$
# $\displaystyle 18: \frac{x - 5}{x - 4}$
# $\displaystyle 19: \frac{- x - 3}{x - 3}$
# $\displaystyle 20: \frac{1 - x}{x + 1}$
# $\displaystyle 21: \frac{1}{t^{2} + 9}$
# $\displaystyle 22: x$
# $\displaystyle 23: \frac{x + 4}{x + 1}$
# $\displaystyle 24: \frac{2 x + y}{x - 2 y}$
# $\displaystyle 25: \frac{4 x^{2} - 1}{x^{2} + 10 x + 25}$
# $\displaystyle 26: 1$
# $\displaystyle 27: x^{3} + x^{2}$
# $\displaystyle 28: \frac{x - 2}{x + 1}$
# $\displaystyle 29: \frac{x}{y z}$
# $\displaystyle 30: \frac{x z}{y}$

# %% [markdown]
# ## Ques. 31-50 . Perform the addition or subtraction and simplify.

# %%
exprs_3 = [
    together(2 + ((x) / (x + 3))),
    together(((2*x - 1) / (x + 4)) - 1),
    together(((1) / (x + 5)) + ((2) / (x - 3))),
    cancel(together(((1) / (x + 1)) + ((1) / (x - 1)))),
    together(((1) / (x + 1)) - ((1) / (x + 2))),
    cancel(together(((x) / (x - 4)) - ((3) / (x + 6)))),
    together(((x) / (x + 1)**2) + ((2) / (x + 1))),
    cancel(together(((5) / (2*x - 3)) - ((3) / (2*x - 3)**2))),
    cancel(together((u + 1) + ((u) / (u + 1)))),
    together((2 / a**2) - (3 / (a*b)) + (4 / b**2)),
    together(((1) / (x**2)) + ((1) / (x**2 + x))),
    together((1 / x) + (1 / x**2) + (1 / x**3)),
    cancel(together(((2) / (x + 3)) - ((1) / (x**2 + 7*x + 12)))),
    cancel(together(((x) / (x**2 - 4)) + ((1) / (x - 2)))),
    cancel(together(((1) / (x + 3)) + ((1) / (x**2 - 9)))),
    cancel(together(((x) / (x**2 + x - 2)) - ((2) / (x**2 - 5*x + 4)))),
    together((2 / x) + (3 / (x - 1)) - (4 / (x**2 - x))),
    cancel(together((x / (x**2 - x - 6)) - (1 / (x + 2)) - (2 / (x - 3)))),
    cancel(together(((1) / (x**2 + 3*x + 2)) - ((1) / (x**2 - 2*x - 3)))),
    cancel(together((1 / (x + 1)) - (2 / (x + 1)**2) + (3 / (x**2 - 1)))),

]

gen_exprs(exprs_3, ques_start=31)
# Out:
# $\displaystyle 31: \frac{3 \left(x + 2\right)}{x + 3}$
# $\displaystyle 32: \frac{x - 5}{x + 4}$
# $\displaystyle 33: \frac{3 x + 7}{\left(x - 3\right) \left(x + 5\right)}$
# $\displaystyle 34: \frac{2 x}{x^{2} - 1}$
# $\displaystyle 35: \frac{1}{\left(x + 1\right) \left(x + 2\right)}$
# $\displaystyle 36: \frac{x^{2} + 3 x + 12}{x^{2} + 2 x - 24}$
# $\displaystyle 37: \frac{3 x + 2}{\left(x + 1\right)^{2}}$
# $\displaystyle 38: \frac{10 x - 18}{4 x^{2} - 12 x + 9}$
# $\displaystyle 39: \frac{u^{2} + 3 u + 1}{u + 1}$
# $\displaystyle 40: \frac{4 a^{2} - 3 a b + 2 b^{2}}{a^{2} b^{2}}$
# $\displaystyle 41: \frac{2 x + 1}{x^{2} \left(x + 1\right)}$
# $\displaystyle 42: \frac{x^{2} + x + 1}{x^{3}}$
# $\displaystyle 43: \frac{2 x + 7}{x^{2} + 7 x + 12}$
# $\displaystyle 44: \frac{2 x + 2}{x^{2} - 4}$
# $\displaystyle 45: \frac{x - 2}{x^{2} - 9}$
# $\displaystyle 46: \frac{x^{2} - 6 x - 4}{x^{3} - 3 x^{2} - 6 x + 8}$
# $\displaystyle 47: \frac{5 x - 6}{x \left(x - 1\right)}$
# ...
